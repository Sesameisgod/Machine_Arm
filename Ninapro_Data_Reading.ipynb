# %%
# 引入 library
import scipy.io as sio
import matplotlib.pyplot as plt
import numpy as np

# %%
# 讀取資料
path = 'DB1_s1/'
mat = 'S1_A1_E1'
data = sio.loadmat((path+mat))
plt.close()

# %%
# 資料結構
data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Mon Jul 28 11:54:15 2014',
#  '__version__': '1.0',
#  '__globals__': [],
#  'emg': array([[0.0684, 0.0024, 0.0024, ..., 0.0488, 0.0024, 0.0342],
#         [0.0586, 0.0024, 0.0024, ..., 0.0415, 0.0024, 0.0293],
#         [0.0562, 0.0024, 0.0024, ..., 0.0391, 0.0024, 0.0244],
#         ...,
#         [0.0024, 0.0024, 0.0024, ..., 0.0342, 0.0024, 0.0073],
#         [0.0024, 0.0024, 0.0024, ..., 0.0366, 0.0024, 0.0073],
#         [0.0024, 0.0024, 0.0024, ..., 0.0391, 0.0024, 0.0024]]),
#  'stimulus': array([[0],
#         [0],
#         [0],
#         ...,
#         [0],
#         [0],
#         [0]], dtype=uint8),
#  'glove': array([[146., 121., 113., ..., 131., 135., 115.],
#         [146., 121., 113., ..., 131., 135., 115.],
#         [146., 121., 113., ..., 131., 135., 115.],
#         ...,
#         [161., 128., 122., ..., 155., 131., 116.],
#         [161., 128., 122., ..., 155., 131., 116.],
# ...

# %%
# 畫出部分資料
begin = 0
end = 6000
# 手套數據
plt.plot(glove.T[5][begin:end])
# 所執行的動作數據(優化後)
plt.plot(restimulus[begin:end]*100)
plt.show()

# %%
emg = data['emg']
glove = data['glove']
stimulus = data['stimulus']
repetition = data['repetition']
restimulus = data['restimulus']
rerepetition = data['rerepetition']

# %%
# 畫出部分手套節點與其餘數據
# 從零開始篹
finger = ['拇指','食指','中指','無名指','小指']
for index,i in enumerate([2,5,8,12,16]):
    print('節點:' + str(i+1)+'\n')
    print(finger[index]+'變化')
    plt.plot(glove.T[i])
    plt.show()
    print('刺激(stimulus)')
    plt.plot(stimulus)
    plt.show()
    print('重複(repetition)')
    plt.plot(repetition)
    plt.show()
    print('再刺激(restimulus)')
    plt.plot(restimulus)
    plt.show()
    print('再重複(rerepetition)')
    plt.plot(rerepetition)
    plt.show()
# Out:
# 節點:3
#
# 拇指變化
# 刺激(stimulus)
# 重複(repetition)
# 再刺激(restimulus)
# 再重複(rerepetition)
# 節點:6
#
# 食指變化
# 刺激(stimulus)
# 重複(repetition)
# 再刺激(restimulus)
# 再重複(rerepetition)
# 節點:9
#
# 中指變化
# 刺激(stimulus)
# 重複(repetition)
# 再刺激(restimulus)
# 再重複(rerepetition)
# 節點:13
#
# 無名指變化
# 刺激(stimulus)
# 重複(repetition)
# 再刺激(restimulus)
# 再重複(rerepetition)
# 節點:17
#
# 小指變化
# 刺激(stimulus)
# 重複(repetition)
# 再刺激(restimulus)
# 再重複(rerepetition)
